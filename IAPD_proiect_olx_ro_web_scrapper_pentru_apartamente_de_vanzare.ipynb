# %% [markdown]
# <a href="https://colab.research.google.com/github/constantintonu/IAPD---proiect/blob/main/IAPD_proiect_olx_ro_web_scrapper_pentru_apartamente_de_vanzare.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install requests beautifulsoup4 lxml
# !pip install pandas openpyxl

# %%
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin
import time

BASE_URL = "https://www.olx.ro"
LISTING_PATH = "/imobiliare/apartamente-garsoniere-de-vanzare/"

# vom salva link-urile unice aici
unique_links = set()
unique_links_partners = set()

# configurarea header-ului

headers = {
    "User-Agent": (
        "Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
        "AppleWebKit/537.36 (KHTML, like Gecko) "
        "Chrome/123.0.0.0 Safari/537.36"
    )
}

for page in range(1,26):  # paginile 1..100
    params = {
        "currency": "EUR",
        "page": page,
    }

    url = BASE_URL + LISTING_PATH
    print(f"[INFO] Descarc pagina {page}: {url} cu params={params}")

    try:
        response = requests.get(url, headers=headers, params=params, timeout=10)
    except Exception as e:
        print(f"[EROARE] Request esuat pentru pagina {page}: {e}")
        continue

    if response.status_code != 200:
        print(f"[AVERTISMENT] Status code {response.status_code} pentru pagina {page}")
        continue

    html = response.text
    with open("resp.html", "w", encoding="utf-8") as f:
      f.write(html);
    soup = BeautifulSoup(html, "lxml")
    body = soup.body

    # 3. gasim toate elementele <div data-cy="l-card">
    cards = body.find_all("div", attrs={"data-cy": "l-card"})
    print(f"  -> Am gasit {len(cards)} card-uri pe pagina {page}")

    olx_count_initial = len(unique_links)
    partenrs_count_initial = len(unique_links_partners)
    for card in cards:
        # 4. in interiorul cardului, cautam DOAR <a class="css-1tqlkj0" href="...">
        a_tags = card.find_all("a", class_="css-1tqlkj0", href=True)

        for a_tag in a_tags:
            #print(f"<a class=css-1tqlkj0>: {a_tag}")
            href = a_tag["href"].strip()

            # 5. transformam in link absolut si il salvam in colectie unica
            full_url = urljoin(BASE_URL, href)
            if(full_url.startswith("https://www.olx.ro/")):
              unique_links.add(full_url)
            else:
              unique_links_partners.add(full_url)

    print(f"  -> Am gasit {len(unique_links) - olx_count_initial} card-uri OLX pe pagina {page}, {len(unique_links_partners) - partenrs_count_initial} card-uri parteneri")
    # pauza mica, sa fim prietenosi cu serverul
    time.sleep(1)

print("\n=== REZULTAT FINAL ===")
print(f"Numar total de anunturi unice gasite: {len(unique_links)}")

# afisam doar primele 20 ca exemplu
for link in list(unique_links)[:20]:
    print(link)

# optional: salvam toate link-urile in fisier
output_file = "olx_apartamente_links.txt"
with open(output_file, "w", encoding="utf-8") as f:
    for link in sorted(unique_links):
        f.write(link + "\n")

output_file = "parteneri_apartamente_links.txt"
with open(output_file, "w", encoding="utf-8") as f:
    for link in sorted(unique_links_partners):
        f.write(link + "\n")

print(f"\nLink-urile au fost salvate in fisierul: {output_file}")
# Out:
# [INFO] Descarc pagina 1: https://www.olx.ro/imobiliare/apartamente-garsoniere-de-vanzare/ cu params={'currency': 'EUR', 'page': 1}
#   -> Am gasit 52 card-uri pe pagina 1
#   -> Am gasit 12 card-uri OLX pe pagina 1, 40 card-uri parteneri
# [INFO] Descarc pagina 2: https://www.olx.ro/imobiliare/apartamente-garsoniere-de-vanzare/ cu params={'currency': 'EUR', 'page': 2}
#   -> Am gasit 52 card-uri pe pagina 2
#   -> Am gasit 8 card-uri OLX pe pagina 2, 43 card-uri parteneri
# [INFO] Descarc pagina 3: https://www.olx.ro/imobiliare/apartamente-garsoniere-de-vanzare/ cu params={'currency': 'EUR', 'page': 3}
#   -> Am gasit 52 card-uri pe pagina 3
#   -> Am gasit 6 card-uri OLX pe pagina 3, 46 card-uri parteneri
# [INFO] Descarc pagina 4: https://www.olx.ro/imobiliare/apartamente-garsoniere-de-vanzare/ cu params={'currency': 'EUR', 'page': 4}
#   -> Am gasit 52 card-uri pe pagina 4
#   -> Am gasit 7 card-uri OLX pe pagina 4, 40 card-uri parteneri
# [INFO] Descarc pagina 5: https://www.olx.ro/imobiliare/apartamente-garsoniere-de-vanzare/ cu params={'currency': 'EUR', 'page': 5}
#   -> Am gasit 52 card-uri pe pagina 5
#   -> Am gasit 5 card-uri OLX pe pagina 5, 46 card-uri parteneri
# [INFO] Descarc pagina 6: https://www.olx.ro/imobiliare/apartamente-garsoniere-de-vanzare/ cu params={'currency': 'EUR', 'page': 6}
#   -> Am gasit 52 card-uri pe pagina 6
#   -> Am gasit 7 card-uri OLX pe pagina 6, 45 card-uri parteneri
# [INFO] Descarc pagina 7: https://www.olx.ro/imobiliare/apartamente-garsoniere-de-vanzare/ cu params={'currency': 'EUR', 'page': 7}
#   -> Am gasit 52 card-uri pe pagina 7
#   -> Am gasit 7 card-uri OLX pe pagina 7, 45 card-uri parteneri
# [INFO] Descarc pagina 8: https://www.olx.ro/imobiliare/apartamente-garsoniere-de-vanzare/ cu params={'currency': 'EUR', 'page': 8}
#   -> Am gasit 52 card-uri pe pagina 8
#   -> Am gasit 4 card-uri OLX pe pagina 8, 46 card-uri parteneri
# [INFO] Descarc pagina 9: https://www.olx.ro/imobiliare/apartamente-garsoniere-de-vanzare/ cu params={'currency': 'EUR', 'page': 9}
#   -> Am gasit 52 card-uri pe pagina 9
#   -> Am gasit 6 card-uri OLX pe pagina 9, 45 card-uri parteneri
# [INFO] Descarc pagina 10: https://www.olx.ro/imobiliare/apartamente-garsoniere-de-vanzare/ cu params={'currency': 'EUR', 'page': 10}
#   -> Am gasit 52 card-uri pe pagina 10
#   -> Am gasit 2 card-uri OLX pe pagina 10, 48 card-uri parteneri
# [INFO] Descarc pagina 11: https://www.olx.ro/imobiliare/apartamente-garsoniere-de-vanzare/ cu params={'currency': 'EUR', 'page': 11}
#   -> Am gasit 52 card-uri pe pagina 11
#   -> Am gasit 2 card-uri OLX pe pagina 11, 49 card-uri parteneri
# [INFO] Descarc pagina 12: https://www.olx.ro/imobiliare/apartamente-garsoniere-de-vanzare/ cu params={'currency': 'EUR', 'page': 12}
#   -> Am gasit 52 card-uri pe pagina 12
#   -> Am gasit 4 card-uri OLX pe pagina 12, 41 card-uri parteneri
# [INFO] Descarc pagina 13: https://www.olx.ro/imobiliare/apartamente-garsoniere-de-vanzare/ cu params={'currency': 'EUR', 'page': 13}
#   -> Am gasit 52 card-uri pe pagina 13
#   -> Am gasit 3 card-uri OLX pe pagina 13, 47 card-uri parteneri
# [INFO] Descarc pagina 14: https://www.olx.ro/imobiliare/apartamente-garsoniere-de-vanzare/ cu params={'currency': 'EUR', 'page': 14}
#   -> Am gasit 52 card-uri pe pagina 14
#   -> Am gasit 1 card-uri OLX pe pagina 14, 50 card-uri parteneri
# [INFO] Descarc pagina 15: https://www.olx.ro/imobiliare/apartamente-garsoniere-de-vanzare/ cu params={'currency': 'EUR', 'page': 15}
#   -> Am gasit 52 card-uri pe pagina 15
#   -> Am gasit 3 card-uri OLX pe pagina 15, 46 card-uri parteneri
# [INFO] Descarc pagina 16: https://www.olx.ro/imobiliare/apartamente-garsoniere-de-vanzare/ cu params={'currency': 'EUR', 'page': 16}
#   -> Am gasit 52 card-uri pe pagina 16
#   -> Am gasit 4 card-uri OLX pe pagina 16, 46 card-uri parteneri
# [INFO] Descarc pagina 17: https://www.olx.ro/imobiliare/apartamente-garsoniere-de-vanzare/ cu params={'currency': 'EUR', 'page': 17}
#   -> Am gasit 52 card-uri pe pagina 17
#   -> Am gasit 5 card-uri OLX pe pagina 17, 45 card-uri parteneri
# [INFO] Descarc pagina 18: https://www.olx.ro/imobiliare/apartamente-garsoniere-de-vanzare/ cu params={'currency': 'EUR', 'page': 18}
#   -> Am gasit 52 card-uri pe pagina 18
#   -> Am gasit 2 card-uri OLX pe pagina 18, 49 card-uri parteneri
# [INFO] Descarc pagina 19: https://www.olx.ro/imobiliare/apartamente-garsoniere-de-vanzare/ cu params={'currency': 'EUR', 'page': 19}
#   -> Am gasit 52 card-uri pe pagina 19
#   -> Am gasit 0 card-uri OLX pe pagina 19, 49 card-uri parteneri
# [INFO] Descarc pagina 20: https://www.olx.ro/imobiliare/apartamente-garsoniere-de-vanzare/ cu params={'currency': 'EUR', 'page': 20}
#   -> Am gasit 52 card-uri pe pagina 20
#   -> Am gasit 3 card-uri OLX pe pagina 20, 47 card-uri parteneri
# [INFO] Descarc pagina 21: https://www.olx.ro/imobiliare/apartamente-garsoniere-de-vanzare/ cu params={'currency': 'EUR', 'page': 21}
#   -> Am gasit 52 card-uri pe pagina 21
#   -> Am gasit 4 card-uri OLX pe pagina 21, 47 card-uri parteneri
# [INFO] Descarc pagina 22: https://www.olx.ro/imobiliare/apartamente-garsoniere-de-vanzare/ cu params={'currency': 'EUR', 'page':
# Link-urile au fost salvate in fisierul: parteneri_apartamente_links.txt

# %%
import re
import csv

def extract_ad_details(url):
    """Intoarce un dict cu detalii despre anunt (sau None daca esueaza)."""
    try:
        resp = requests.get(url, headers=headers, timeout=10)
    except Exception as e:
        print(f"[EROARE] Request esuat pentru anunt: {url} -> {e}")
        return None

    if resp.status_code != 200:
        print(f"[AVERTISMENT] Status code {resp.status_code} pentru anunt: {url}")
        return None

    soup = BeautifulSoup(resp.text, "lxml")

    # TITLU
    title = None
    title_tag = soup.find(attrs={"data-cy": "ad_title"})
    if title_tag:
        title = title_tag.get_text(strip=True)
    else:
        h1 = soup.find("h1")
        if h1:
            title = h1.get_text(strip=True)

    # PRET
    price = None
    price_container = soup.find(attrs={"data-testid": "ad-price-container"})
    if price_container:
        price = price_container.get_text(" ", strip=True)
    else:
        price_tag = soup.find(attrs={"data-testid": "ad-price"})
        if price_tag:
            price = price_tag.get_text(" ", strip=True)

    # LOCATIE + DATA
    location_date = None
    loc_tag = soup.find(attrs={"data-testid": "location-date"})
    if loc_tag:
        location_date = loc_tag.get_text(" ", strip=True)

    # SUPRAFATA (m²) – cautam text cu m²
    surface_m2 = None
    text_with_m2 = soup.find(string=re.compile(r"\b\d+\s*(m²|m2)\b"))
    if text_with_m2:
        # extragem doar numarul
        m = re.search(r"(\d+)\s*(m²|m2)", text_with_m2)
        if m:
            surface_m2 = m.group(1)

    return {
        "url": url,
        "title": title,
        "price": price,
        "location_date": location_date,
        "surface_m2": surface_m2,
    }

# Parcurgem TOATE link-urile stranse mai sus
rows = []
print("\n=== INCEP EXTRAGERE DETALII ANUNTURI ===")

for i, ad_url in enumerate(unique_links, start=1):
    print(f"[{i}/{len(unique_links)}] Procesez: {ad_url}")
    data = extract_ad_details(ad_url)
    if data:
        rows.append(data)
    time.sleep(1)  # pauza intre anunturi

print(f"\nAm extras detalii pentru {len(rows)} anunturi.")
# Out:
# === INCEP EXTRAGERE DETALII ANUNTURI ===
# [1/155] Procesez: https://www.olx.ro/d/oferta/vanzare-apartament-cu-3-camere-dec-in-braila-calea-calarasilor-nou-IDjW2E7.html
# [2/155] Procesez: https://www.olx.ro/d/oferta/apartament-3-camere-tip-5-palladium-residence-1-IDk1EDn.html
# [3/155] Procesez: https://www.olx.ro/d/oferta/apartament-de-vanzare-IDjRfib.html
# [4/155] Procesez: https://www.olx.ro/d/oferta/apartament-intabulat-2-camere-decomandat-top-proprietar-imobil-locuit-IDjV3tY.html
# [5/155] Procesez: https://www.olx.ro/d/oferta/apartament-3-camere-110mp-utili-baneasa-aviatiei-IDk3dsq.html
# [6/155] Procesez: https://www.olx.ro/d/oferta/apartament-3-camere-renovat-nou-etaj-1-mobilat-si-utilat-nou-cluj-IDjUKLI.html
# [7/155] Procesez: https://www.olx.ro/d/oferta/vand-apartament-2-camerere-in-craiova-craiovita-promenada-penny-IDjWnpf.html
# [8/155] Procesez: https://www.olx.ro/d/oferta/3-camere-mansarda-bragadiru-direct-dezvoltator-pret-fara-tva-IDjxvU9.html
# [9/155] Procesez: https://www.olx.ro/d/oferta/oferta-black-friday-vanzare-apartament-3-camere-zona-cantacuzino-IDjUpZ9.html
# [10/155] Procesez: https://www.olx.ro/d/oferta/nicolina-cug-apartament-3-camere-80-mp-la-bulevard-cu-centrala-IDk13hs.html
155] Procesez: https://www.olx.ro/d/oferta/apartament-3-camere-mega-oferta-direct-dezvoltator-orice-creditare-IDjUCCv.html
# [140/155] Procesez: https://www.olx.ro/d/oferta/garsoniera-de-vanzare-la-cheie-davinci-de-la-proprietar-IDk2mhZ.html
# [141/155] Procesez: https://www.olx.ro/d/oferta/garsoniera-renovata-si-utilata-IDk1f6z.html
# [142/155] Procesez: https://www.olx.ro/d/oferta/apartament-2-camere-aviatiei-park-herastrau-IDj68ov.html
# [143/155] Procesez: https://www.olx.ro/d/oferta/pers-fizica-vand-apartament-2-camere-govandari-zona-victoria-IDk03Vg.html
# [144/155] Procesez: https://www.olx.ro/d/oferta/apartament-2-camere-craiovita-lux-IDk2XKo.html
# [145/155] Procesez: https://www.olx.ro/d/oferta/apartamente-noi-galati-IDjFfo1.html
# [146/155] Procesez: https://www.olx.ro/d/oferta/apartamente-cu-3-camere-direct-de-la-dezvoltator-IDinBgf.html
# [147/155] Procesez: https://www.olx.ro/d/oferta/apartament-3-camere-de-exceptie-finisaje-premium-IDk2MOn.html
# [148/155] Procesez: https://www.olx.ro/d/oferta/apartamente-noi-de-vanzare-in-codlea-IDjqVcV.html
# [149/155] Procesez: https://www.olx.ro/d/oferta/pf-apartament-2-camere-cf-finisat-60mp-terasa-garaj-view-elite-city-IDjPKgK.html
# [150/155] Procesez: https://www.olx.ro/d/oferta/apartament-cu-doua-camere-zona-nufarul-IDjTSOw.html
# [151/155] Procesez: https://www.olx.ro/d/oferta/persoana-fizica-vand-schimb-apart-2-cam-d-2-balc-podu-ros-IDiFi2O.html
# [152/155] Procesez: https://www.olx.ro/d/oferta/apartament-tip-penthous-la-super-pret-IDjOyZE.html
# [153/155] Procesez: https://www.olx.ro/d/oferta/apartament-cu-2-camere-sfantu-gheorghe-IDk0vmZ.html
# [154/155] Procesez: https://www.olx.ro/d/oferta/apartament-de-vanzare-mamaia-nord-luma-resident-1-IDjzprn.html
# [155/155] Procesez: https://www.olx.ro/d/oferta/superoferta-tva9-ap-de-vanzare-aradului-direct-de-la-dezvoltator-IDj1l1J.html
#
# Am extras detalii pentru 155 anunturi.

# %%
output_csv = "olx_apartamente_detalii.csv"

fieldnames = ["url", "title", "price", "location_date", "surface_m2"]

with open(output_csv, "w", newline="", encoding="utf-8") as f:
    writer = csv.DictWriter(f, fieldnames=fieldnames)
    writer.writeheader()
    for row in rows:
        writer.writerow(row)

print(f"Fisierul CSV a fost salvat ca: {output_csv}")
# Out:
# Fisierul CSV a fost salvat ca: olx_apartamente_detalii.csv

# %% [markdown]
# Parsare anunt v2

# %%
import requests
from bs4 import BeautifulSoup

headers = {
    "User-Agent": (
        "Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
        "AppleWebKit/537.36 (KHTML, like Gecko) "
        "Chrome/123.0.0.0 Safari/537.36"
    )
}

def fetch_html(url: str) -> str:
    resp = requests.get(url, headers=headers, timeout=10)
    resp.raise_for_status()
    return resp.text

def parse_storia_details(html: str) -> dict:
    """
    Primește HTML-ul unei pagini de anunț Storia și
    întoarce un dict {eticheta: valoare} pentru toate
    perechile de tip:
      'Suprafață utilă' -> '45 m²',
      'Numărul de camere' -> '2', etc.
    """
    soup = BeautifulSoup(html, "lxml")
    body = soup.body

    if body is None:
        return {}

    # 1. Găsim containerul principal de detalii (AdDetailsBase)
    details_root = body.find("div", attrs={"data-sentry-component": "AdDetailsBase"})
    if details_root is None:
        # fallback: ce ai pus în exemplu
        details_root = body.find("div", attrs={"data-sentry-element": "StyledListContainer"})
    if details_root is None:
        return {}

    details = {}

    # 2. În interior, toate blocurile de tip "ItemGridContainer"
    #    fiecare conține: <div>Label</div> + <div>Valoare</div>
    containers = details_root.select('[data-sentry-element="ItemGridContainer"]')

    for grid in containers:
        # luăm DOAR div-urile directe, ca să nu prindem alte chestii
        children = [
            d for d in grid.find_all("div", recursive=False)
            if d.get_text(strip=True)
        ]

        if len(children) < 2:
            continue

        label = children[0].get_text(" ", strip=True)
        value = children[1].get_text(" ", strip=True)

        # scoatem ":" de la finalul label-ului, dacă există
        if label.endswith(":"):
            label = label[:-1].strip()

        details[label] = value

    return details

# %% [markdown]
# Exemplu extragere data dintr-un singur anunt

# %%
url = "https://www.storia.ro/ro/oferta/vanzare-apartament-2-camere-in-ploiesti-zona-nord-cameliei-IDDRz6.html"

html = fetch_html(url)
detalii = parse_storia_details(html)

for k, v in detalii.items():
    print(f"{k}: {v}")
# Out:
# Suprafață utilă: 45 m²
# Numărul de camere: 2
# Încălzire: fără informații
# Etaj: 4/4
# Chirie: fără informații
# Stare: gata de utilizare
# Tip proprietate: locuință nouă
# Forma de proprietate: fără informații
# Liber de la: fără informații
# Tip vânzător: agenție
# Informații suplimentare: fără informații
# Anul construcției: 1967
# Lift: nu
# Facilități: aer condiționat

# %% [markdown]
# Extragere date din toate anunturile:

# %%
for i, ad_url in enumerate(unique_links_partners, start=1):
    print(f"[{i}/{len(unique_links_partners)}] Procesez: {ad_url}")
    try:
        try:
            html = fetch_html(ad_url)
        except Exception as e:
            print(f"    ⚠ fetch_html a eșuat, retry 1x...")
            html = fetch_html(ad_url)  # retry once

        details = parse_storia_details(html)

        if details:
            details["url"] = ad_url
            print(f"anunt {i}: {details}")
            all_ads_data.append(details)

    except Exception as e:
        print(f"  -> ❌ Ignor eroarea și continui: {e}")
        continue
# Out:
# [1/1135] Procesez: https://www.storia.ro/ro/oferta/apartament-1-camer-zona-centrul-vechi-IDA2Cw.html
# anunt 1: {'Suprafață utilă': '31 m²', 'Numărul de camere': '1', 'Încălzire': 'fără informații', 'Etaj': '2', 'Chirie': 'fără informații', 'Stare': 'fără informații', 'Tip proprietate': 'locuință utilizată', 'Forma de proprietate': 'fără informații', 'Liber de la': 'fără informații', 'Tip vânzător': 'agenție', 'Informații suplimentare': 'fără informații', 'Anul construcției': '2022', 'Lift': 'nu', 'Facilități': 'mobilier', 'Siguranță': 'supraveghere video', 'url': 'https://www.storia.ro/ro/oferta/apartament-1-camer-zona-centrul-vechi-IDA2Cw.html'}
# [2/1135] Procesez: https://www.storia.ro/ro/oferta/locuinta-moderna-cu-o-camera-mutare-rapida-sos-salaj-rahova-IDEQcK.html
# anunt 2: {'Suprafață utilă': '38 m²', 'Numărul de camere': '1', 'Încălzire': 'centrală pe gaz', 'Etaj': '5/6', 'Chirie': 'fără informații', 'Stare': 'gata de utilizare', 'Tip proprietate': 'locuință utilizată', 'Forma de proprietate': 'drept de proprietate', 'Liber de la': '2025-11-27', 'Tip vânzător': 'agenție', 'Informații suplimentare': 'balcon bucătărie separată', 'Anul construcției': '2014', 'Lift': 'da', 'Material de construcție': 'beton', 'Tip geamuri': 'plastic', 'Facilități': 'mobilier cuptor plită frigider', 'Siguranță': 'interfon uși / ferestre blindate', 'Media': 'telefon internet', 'url': 'https://www.storia.ro/ro/oferta/locuinta-moderna-cu-o-camera-mutare-rapida-sos-salaj-rahova-IDEQcK.html'}
# [3/1135] Procesez: https://www.storia.ro/ro/oferta/3-camere-cu-terasa-54-mp-fundeni-dobroesti-IDEr5L.html
# anunt 3: {'Suprafață utilă': '68.5 m²', 'Numărul de camere': '3', 'Încălzire': 'centrală pe gaz', 'Etaj': '3/3', 'Chirie': 'fără informații', 'Stare': 'gata de utilizare', 'Tip proprietate': 'locuință utilizată', 'Forma de proprietate': 'drept de proprietate', 'Liber de la': 'fără informații', 'Tip vânzător': 'agenție', 'Informații suplimentare': 'fără informații', 'Anul construcției': '2025', 'Lift': 'nu', 'Tip clădire': 'ansamblu de apartamente', 'Material de construcție': 'beton', 'Tip geamuri': 'plastic', 'Media': 'telefon', 'url': 'https://www.storia.ro/ro/oferta/3-camere-cu-terasa-54-mp-fundeni-dobroesti-IDEr5L.html'}
# [4/1135] Procesez: https://www.storia.ro/ro/oferta/apartament-2-camere-i-finisat-i-burdujeni-IDEGOd.html
# anunt 4: {'Suprafață utilă': '52 m²', 'Numărul de camere': '2', 'Încălzire': 'centrală pe gaz', 'Etaj': 'parter/4', 'Chirie': 'fără informații', 'Stare': 'gata de utilizare', 'Tip proprietate': 'locuință utilizată', 'Forma de proprietate': 'drept de proprietate', 'Liber de la': '2025-11-20', 'Tip vânzător': 'agenție', 'Informații suplimentare': 'fără informații', 'Lift': 'nu', 'Tip clădire': 'ansamblu de apartamente', 'Material de construcție': 'beton', 'Tip geamuri': 'plastic', 'url': 'https://www.storia.ro/ro/oferta/apartament-2-camere-i-finisat-i-burdujeni-IDEGOd.html'}
# [5/1135] Procesez: https://www.storia.ro/ro/oferta/apartament-4-camere-terasa-94mp-licurg-2-cartierul-armenesc-IDD8O0.html
# anunt 5: {'Suprafață utilă': '119 m²', 'Numărul de camere': '4', 'Încălzire': 'fără informații', 'Etaj': '3/3', 'Chirie': 'fără informații', 'Stare': 'fără informații', 'Tip proprietate': 'locuință utilizată', 'Forma de proprietate': 'fără informații', 'Liber de la': 'fără informații', 'Tip vânzător': 'agenție', 'Informații suplimentare': 'terasă beci scară interioară', 'Anul construcției': '2023', 'Lift': 'da', 'Tip clădire': 'ansamblu de apartamente', 'Material de construcție': 'beton', 'Facilități': 'aer condiționat', 'Siguranță': 'alarmă interfon supraveghere video uși / ferestre blindate', 'url': 'https://www.storia.ro/ro/oferta/apartament-4-camere-terasa-94mp-licurg-2-cartierul-armenesc-IDD8O0.html'}
# [6/1135] Procesez: https://www.storia.ro/ro/oferta/apartament-modern-cu-2-camere-bloc-nou-balcon-generos-parcare-IDFexk.html
# anunt 6: {'Suprafață utilă': '37.5 m²', 'Numărul de camere': '2', 'Încălzire': 'centrală pe gaz', 'Etaj': '3/3', 'Chirie': 'fără informații', 'Stare': 'gata de utilizare', 'Tip proprietate': 'locuință utilizată', 'Forma de proprietate': 'drept de proprietate', 'Liber de la': '2025-11-27', 'Tip vânzător': 'agenție', 'Informații suplimentare': 'balcon', 'Anul construcției': '2022', 'Lift': 'nu', 'Tip clădire': 'ansamblu de apartamente', 'Material de construcție': 'cărămidă cu goluri', 'Tip geamuri': 'plastic', 'Facilități': 'cuptor frigider aer condiționat', 'Siguranță': 'uși / ferestre blindate interfon', 'Media': 'internet', 'url': 'https://www.storia.ro/ro/oferta/apartament-modern-cu-2-camere-bloc-nou-balcon-generos-parcare-IDFexk.html'}
# [7/1135] Procesez: https://www.storia.ro/ro/oferta/apartament-cu-3-camere-green-residence-nufarul-IDCYLU.html
# anunt 7: {'Suprafață utilă': '61.1 m²', 'Numărul de camere': '3', 'Încălzire': 'fără informații', 'Etaj': 'fără informații', 'Chirie': 'fără informații', 'Stare': 'gata de utilizare', 'Tip proprietate': 'locuință nouă', 'Forma de proprietate': 'drept de proprietate', 'Liber de la': 'fără informații', 'Tip vânzător': 'agenție', 'Informații suplimentare': 'balcon', 'Anul construcției': '2025', 'Lift': 'da', 'Tip clădire': 'bloc', 'Material de construcție': 'cărămidă', 'Tip geamuri': 'aluminiu', 'Facilități': 'aer condiționat', 'Siguranță': 'alarmă uși / ferestre blindate interfon supraveghere video', 'Media': 'cablu tv internet telefon', 'url': 'https://www.storia.ro/ro/oferta/apartament-cu-3-camere-green-residence-nufarul-IDCYLU.html'}
# [8/1135] Procesez: https://www.storia.ro/ro/oferta/apartament-de-vanzare-victoriei-garaj-i-curte-proprie-IDCBwz.html
# anunt 8: {'Suprafață utilă': '93 m²', 'Numărul de camere': '3', 'Încălzire': 'centralizată', 'Etaj': '1', 'Chirie': 'fără informații', 'Stare': 'fără informații', 'Tip proprietate': 'locuință utilizată', 'Forma de proprietate': 'fără informații', 'Liber de la': 'fără informații', 'Tip vânzător': 'agenție', 'Informații suplimentare': 'fără informații', 'Anul construcției': '2009', 'Lift': 'nu', 'Siguranță': 'uși / ferestre blindate', 'url': 'https://www.storia.ro/ro/oferta/apartament-de-vanzare-victoriei-garaj-i-curte-proprie-IDCBwz.html'}
# [9/1135] Procesez: https://www.storia.ro/ro/oferta/ap-4-camere-in-imobil-tip-vila-121-74-mp-utili-terasa-28-mp-IDD9UC.html
# anunt 9: {'Suprafață utilă': '121.74 m²', 'Numărul de camere': '4', 'Încălzire': 'centrală pe gaz', 'Etaj': '1/2', 'Chirie': 'fără informații', 'Stare': 'fără informații', 'Tip proprietate': 'locuință nouă', 'Forma de proprietate': 'drept de proprietate', 'Liber de la': '2025-11-07', 'Tip vânzător': 'agenție', 'Informații suplimentare': 'balcon terasă garaj beci scară interioară', 'Anul construcției': '2025', 'Lift': 'nu', 'Tip clădire': 'ansamblu de apartamente', 'Material de construcție': 'cărămidă', 'Tip geamuri': 'plastic', 'Siguranță': 'uși / ferestre blindate interfon', 'url': 'https://www.storia.ro/ro/oferta/ap-4-camere-in-imobil-tip-vila-121-74-mp-utili-terasa-28-mp-IDD9UC.html'}
# [10/1135] Procesez: https://www.storia.ro/ro/oferta/garsoniera-cartier-militari-residence-mutare-imediata-IDFILv.html
# anunt 10: {'Suprafață utilă': '32 m²', 'Numărul de camere': '1', 'Încălzire': 'centrală pe gaz', 'Etaj': '1/3', 'Chirie': 'fără informații', 'Stare': 'gata de utilizare', 'Tip proprietate': 'locuință nouă', 'Forma de proprietate': 'drept de proprietate', 'Liber de la': '2025-11-27', 'Tip vânzător': 'agenție', 'Informații suplimentare': 'balcon', 'Anul construcției': '2025', 'Lift': 'da', 'Material de construcție': 'beton', 'Tip geamuri': 'plastic', 'Siguranță': 'interfon supraveghere video uși / ferestre blindate', 'Media': 'internet', 'url': 'https://www.storia.ro/ro/oferta/garsoniera-cartier-militari-residence-mutare-imediata-IDFILv.html'}
# [11/1135] Procesez: https://www.storia.ro/ro/oferta/apartament-de-2-camere-zona-centrala-IDF21V.html
# anunt 11: {'Suprafață utilă': '54 m²', 'Numărul de camere': '2', 'Încălzire': 'centrală pe gaz', 'Etaj': '4/5', 'Chirie': 'fără informații', 'Stare': 'gata de utilizare', 'Tip proprietate': 'locuință utilizată', 'Forma de proprietate': 'drept de proprietate', 'Liber de la': '2025-11-27', 'Tip vânzător': 'agenție', 'Informații suplimentare': 'fără informații', 'Anul construcției': '1990', 'Lift': 'nu', 'Tip clădire': 'ansamblu de apartamente', 'Material de construcție': 'placa de beton', 'Tip geamuri': 'plastic', 'Siguranță': 'uși / ferestre blindate interfon', 'url': 'https://www.storia.ro/ro/oferta/apartament-de-2-camere-zona-centrala-IDF21V.html'}
# [12/1135] Procesez: https://www.storia.ro/ro/oferta/apartament-spatios-3-camere-decomandat-zona-rahova-comision-0-IDFcNa.html
# anunt 12: {'Suprafață utilă': '80.6 m²', 'Numărul de camere': '3', 'Încălzire': 'centrală pe gaz', 'Etaj': '5/9', 'Chirie': 'fără informații', 'Stare': 'în construcție', 'Tip proprietate': 'locuință nouă', 'Forma de proprietate': 'drept de proprietate', 'Liber de la': 'fără informații', 'Tip vânzător': 'agenție', 'Informații suplimentare': 'balcon bucătărie separată', 'Anul construcției': '2025', 'Lift': 'da', 'Tip clădire': 'ansamblu de apartamente', 'Material de construcție': 'beton', 'Tip geamuri': 'plastic', 'Siguranță': 'interfon supraveghere video uși / ferestre blindate', 'Media': 'telefon internet cablu tv', 'url': 'https://www.storia.ro/ro/oferta/apartament-spatios-3-camere-decomandat-zona-rahova-comision-0-IDFcNa.html'}
# [13/1135] Procesez: https://www.storia.ro/ro/oferta/apartament-2-camere-et9-10-zona-semicentrala-gara-mare-IDBBdz.html
# anunt 13: {'Suprafață utilă': '55 m²', 'Numărul de camere': '2', 'Încălzire': 'fără informații', 'Etaj': '9/10', 'Chirie': 'fără informații', 'Stare': 'gata de utilizare', 'Tip proprietate': 'locuință utilizată', 'Forma de proprietate': 'drept de proprietate', 'Liber de la': '2025-08-19', 'Tip vânzător': 'agenție', 'Informații suplimentare': 'balcon', 'Anul construcției': '1980', 'Lift': 'nu', 'Tip clădire': 'ansamblu de apartamente', 'Media': 'telefon internet cablu tv', 'url': 'https://www.storia.ro/ro/oferta/apartament-2-camere-et9-10-zona-semicentrala-gara-mare-IDBBdz.html'}
# [14/1135] Procesez: https://www.storia.ro/ro/oferta/garsoniera-decomandata-32-mp-zona-facultatea-de-agronomie-IDFpLv.html
# anunt 14: {'Suprafață utilă': '32 m²', 'Numărul de camere': '1', 'Încălzire': 'centrală pe gaz', 'Etaj': 'demisol/4', 'Chirie': 'fără informații', 'Stare': 'fără informații', 'Tip proprietate': 'locuință nouă', 'Forma de proprietate': 'drept de proprietate', 'Liber de la': '2025-11-13', 'Tip vânzător': 'agenție', 'Informații suplimentare': 'fără informații', 'Anul construcției': '2025', 'Lift': 'nu', 'Tip clădire': 'ansamblu de apartamente', 'Tip geamuri': 'plastic', 'Facilități': 'cuptor frigider mașină de spălat mașină de spălat vasele', 'Siguranță': 'uși / ferestre blindate interfon', 'Media': 'internet', 'url': 'https://www.storia.ro/ro/oferta/garsoniera-decomandata-32-mp-zona-facultatea-de-agronomie-IDFpLv.html'}
# [15/1135] Procesez: https://www.storia.ro/ro/oferta/apartament-4-camere-ultracentral-IDDFc7.html
# anunt 15: {'Suprafață utilă': '103 m²', 'Numărul de camere': '4', 'Încălzire': 'fără informații', 'Etaj': 'parter/1', 'Chirie': 'fără informații', 'Stare': 'gata de utilizare', 'Tip proprietate': 'locuință utilizată', 'Forma de proprietate': 'drept de proprietate', 'Liber de la': '2025-11-27', 'Tip vânzător': 'agenție', 'Informații suplimentare': 'fără informații', 'Anul construcției': '1980', 'Lift': 'nu', 'Tip clădire': 'ansamblu de apartamente', 'Material de construcție': 'cărămidă', 'Media': 'telefon internet cablu tv', 'url': 'https://www.storia.ro/ro/oferta/apartament-4-camere-ultracentral-IDDFc7.html'}
# [16/1135] Procesez: https://www.storia.ro/ro/oferta/apartament-doua-camere-parcul-trandafirilor-IDFiqM.html
# anunt 16: {'Suprafață utilă': '55.6 m²', 'Numărul de camere': '2', 'Încălzire': 'centrală pe gaz', 'Etaj': '6/8', 'Chirie': 'fără informații', 'Stare': 'gata de utilizare', 'Tip proprietate': 'locuință utilizată', 'Forma de proprietate': 'drept de proprietate', 'Liber de la': '2025-11-26', 'Tip vânzător': 'agenție', 'Informații suplimentare': 'balcon debara bucătărie separată', 'Anul construcției': '1987', 'Lift': 'nu', 'Tip clădire': 'ansamblu de apartamente', 'Material de construcție': 'altul', 'Facilități': 'mobilier cuptor plită frigider mașină de spălat', 'Siguranță': 'interfon uși / ferestre blindate', 'Media': 'internet', 'url': 'https://www.storia.ro/ro/oferta/apartament-doua-camere-parcul-trandafirilor-IDFiqM.html'}
# [17/1135] Procesez: https://www.storia.ro/ro/oferta/garsoniera-cartier-militari-residence-mutare-imediata-IDFILw.html
# anunt 17: {'Suprafață utilă': '32 m²', 'Numărul de camere': '1', 'Încălzire': 'centrală pe gaz', 'Etaj': '1/3', 'Chirie': 'fără informații', 'Stare': 'gata de utilizare', 'Tip proprietate': 'locuință nouă', 'Forma de proprietate': 'drept de proprietate', 'Liber de la': '2025-11-27', 'Tip vânzător': 'agenție', 'Informații suplimentare': 'balcon', 'Anul construcției': '2025', 'Lift': 'da', 'Material de construcție': 'beton', 'Tip geamuri': 'plastic', 'Siguranță': 'interfon supraveghere video uși / ferestre blindate', 'Media': 'internet', 'url': 'https://www.storia.ro/ro/oferta/garsoniera-cartier-militari-residence-mutare-imediata-IDFILw.html'}
# [18/1135] Procesez: https://www.storia.ro/ro/oferta/garsoniera-decomandata-aer-conditionat-balcon-5-24-etaj-1-2-IDEDvD.html
# anunt 18: {'Suprafață utilă': '36.52 m²', 'Numărul de camere': '1', 'Încălzire': 'centrală pe gaz', 'Etaj': '1/2', 'Chirie': 'fără informații', 'Stare': 'gata de utilizare', 'Tip proprietate': 'locuință nouă', 'Forma de proprietate': 'drept de proprietate', 'Liber de la': 'fără informații', 'Tip vânzător': 'agenție', 'Informații suplimentare': 'balcon', 'Anul construcției': '2025', 'Lift': 'nu', 'Material de construcție': 'cărămidă', 'Facilități': 'aer condiționat', 'Siguranță': 'interfon obloane', 'Media': 'telefon internet cablu tv', 'url': 'https://www.storia.ro/ro/oferta/garsoniera-decomandata-aer-conditionat-balcon-5-24-etaj-1-2-IDEDvD.html'}
# [19/1135] Procesez: https://www.storia.ro/ro/oferta/de-vanzare-apartament-cu-4-camere-in-zona-ultracentrala-IDEN40.html
# anunt 19: {'Suprafață utilă': '65.3 m²', 'Numărul de camere': '4', 'Încălzire': 'centralizată', 'Etaj': '4', 'Chirie': 'fără informații', 'Stare': 'fără informații', 'Tip proprietate': 'locuință utilizată', 'Forma de proprietate': 'fără informații', 'Liber de la': 'fără informații', 'Tip vânzător': 'agenție', 'Informații suplimentare': 'balcon', 'Anul construcției': '1980', 'Lift': 'nu', 'Facilități': 'mobilier aer condiționat', 'Siguranță': 'uși / ferestre blindate', 'url': 'https://www.storia.ro/ro/oferta/de-vanzare-apartament-cu-4-camere-in-zona-ultracentrala-IDEN40.html'}
# [20/1135] Procesez: https://www.storia.ro/ro/oferta/3-camere-in-complex-rezidenial-premium-comision-0-cumprtor-IDCIgg.html
# anunt 20: {'Suprafață utilă': '116 m²', 'Numărul de camere': '3', 'Încălzire': 'centrală pe gaz', 'Etaj': '1/3', 'Chirie': 'fără informații', 'Stare': 'în construcție', 'Tip proprietate': 'locuință nouă', 'Forma de proprietate': 'drept de proprietate', 'Liber de la': '2025-11-27', 'Tip vânzător': 'agenție', 'Informații suplimentare': 'balcon grădină garaj bucătărie separată', 'Anul construcției': '2025', 'Lift': 'da', 'Tip clădire': 'ansamblu de apartamente', 'Material de construcție': 'beton celular', 'Tip geamuri': 'aluminiu', 'Siguranță': 'interfon supraveghere video uși / ferestre blindate', 'Media': 'telefon internet cablu tv', 'url': 'https://www.storia.ro/ro/oferta/3-camere-in-complex-rezidenial-premium-comision-0-cumprtor-IDCIgg.html'}
# [21/1135] Procesez: https://www.storia.ro/ro/oferta/apartament-2-camere-confort-2-zona-hipodrom-IDrVIu.html
# anunt 21: {'Suprafață utilă': '35 m²', 'Numărul de camere': '2', 'Încălzire': 'centralizată', 'Etaj': '4/4', 'Chirie': 'fără informații', 'Stare': 'gata de utilizare', 'Tip proprietate': 'locuință nouă', 'Forma de proprietate': 'fără informații', 'Liber de la': 'fără informații', 'Tip vânzător': 'agenție', 'Informații suplimentare': 'balcon', 'Anul construcției': '1978', 'Lift': 'nu', 'Facilități': 'aer condiționat', 'url': 'https://www.storia.ro/ro/oferta/apartament-2-camere-confort-2-zona-hipodrom-IDrVIu.html'}
# [22/1135] Procesez: https://www.storia.ro/ro/oferta/apartament-2-camere-semifinisat-54mp-bloc-nou-intre-lacuri-residence-IDFv2J.html
# anunt 22: {'Suprafață utilă': '54 m²', 'Numărul de camere': '2', 'Încălzire': 'fără informații', 'Etaj': '2/4', 'Chirie': 'fără informații', 'Stare': 'gata de utilizare', 'Tip proprietate': 'locuință nouă', 'Forma de proprietate': 'drept de proprietate', 'Liber de la': '2025-11-06', 'Tip vânzător': 'agenție', 'Informații suplimentare': 'fără informații', 'Anul construcției': '2025', 'Lift': 'nu', 'Tip clădire': 'ansamblu de apartamente', 'url': 'https://www.storia.ro/ro/oferta/apartament-2-camere-semifinisat-54mp-bloc-nou-intre-lacuri-residence-IDFv2J.html'}
# [23/1135] Procesez: https://www.storia.ro/ro/oferta/apartament-2-camere-mamaia-IDD3Q2.html
# anunt 23: {'Suprafață utilă': '39 m²', 'Numărul de camere': '2', 'Încălzire': 'centrală pe gaz', 'Etaj': '1', 'Chirie': 'fără informații', 'Stare': 'gata de utilizare', 'Tip proprietate': 'locuință utilizată', 'Forma de proprietate': 'drept de proprietate', 'Liber de la': '2025-11-27', 'Tip vânzător': 'agenție', 'Informații suplimentare': 'balcon', 'Anul construcției': '2018', 'Lift': 'da', 'Tip clădire': 'ansamblu de apartamente', 'Facilități': 'mobilier cuptor plită frigider mașină de spălat TV aer condiționat', 'Siguranță': 'interfon supraveghere video', 'Media': 'telefon internet cablu tv', 'url': 'https://www.storia.ro/ro/oferta/apartament-2-camere-mamaia-IDD3Q2.html'}
# [24/1135] Procesez: https://www.storia.ro/ro/oferta/apartament-2-camere-decomandat-acces-metrou-aparatorii-patriei-IDF28W.html
# anunt 24: {'Suprafață utilă': '58 m²', 'Numărul de camere': '2', 'Încălzire': 'centrală pe gaz', 'Etaj': '2/5', 'Chirie': 'fără informații', 'Stare': 'în construcție', 'Tip proprietate': 'locuință nouă', 'Forma de proprietate': 'drept de proprietate', 'Liber de la': 'fără informații', 'Tip vânzător': 'agenție', 'Informații suplimentare': 'balcon bucătărie separată', 'Anul construcției': '2025', 'Lift': 'da', 'Tip clădire': 'ansamblu de apartamente', 'Material de construcție': 'beton', 'Tip geamuri': 'plastic', 'Facilități': 'aer condiționat', 'Siguranță': 'interfon uși / ferestre blindate', 'Media': 'internet', 'url': 'https://www.storia.ro/ro/oferta/apartament-2-camere-decomandat-acces-metrou-aparatorii-patriei-IDF28W.html'}
# [25/1135] Procesez: https://www.storia.ro/ro/oferta/garsoniera-mobilata-si-utilata-dimitrie-leonida-apollo-residence-IDERnQ.html
# anunt 25: {'Suprafață utilă': '30.24 m²', 'Numărul de camere': '1', 'Încălzire': 'centrală pe gaz', 'Etaj': 'parter', 'Chirie': 'fără informații', 'Stare': 'gata de utilizare', 'Tip proprietate': 'locuință utilizată', 'Forma de proprietate': 'drept de proprietate', 'Liber de la': '2025-11-27', 'Tip vânzător': 'agenție', 'Informații suplimentare': 'fără informații', 'Lift': 'nu', 'Material de construcție': 'beton', 'Tip geamuri': 'plastic', 'Facilități': 'mobilier frigider mașină de spălat TV aer condiționat', 'Siguranță': 'interfon uși / ferestre blindate', 'Media': 'telefon internet cablu tv', 'url': 'https://www.storia.ro/ro/oferta/garsoniera-mobilata-si-utilata-dimitrie-leonida-apollo-residence-IDERnQ.html'}
# [26/1135] Procesez: https://www.storia.ro/ro/oferta/apartament-cu-1-5-camere-n-zona-parneava-IDDThJ.html
# anunt 26: {'Suprafață utilă': '41.07 m²', 'Numărul de camere': '1', 'Încălzire': 'centrală pe gaz', 'Etaj': '2/4', 'Chirie': 'fără informații', 'Stare': 'în construcție', 'Tip proprietate': 'locuință nouă', 'Forma de proprietate': 'drept de proprietate', 'Liber de la': '2025-11-27', 'Tip vânzător': 'agenție', 'Informații suplimentare': 'terasă', 'Anul construcției': '2025', 'Lift': 'da', 'Tip clădire': 'ansamblu de apartamente', 'Material de construcție': 'beton', 'Tip geamuri': 'plastic', 'Facilități': 'aer condiționat', 'Siguranță': 'uși / ferestre blindate supraveghere video', 'Media': 'telefon internet cablu tv', 'url': 'https://www.storia.ro/ro/oferta/apartament-cu-1-5-camere-n-zona-parneava-IDDThJ.html'}
# [27/1135] Procesez: https://www.storia.ro/ro/oferta/apartament-cu-2-camere-n-zona-confecii-IDDTla.html
# anunt 27: {'Suprafață utilă': '61.1 m²', 'Numărul de camere': '2', 'Încălzire': 'centrală pe gaz', 'Etaj': '4/4', 'Chirie': 'fără informații', 'Stare': 'în construcție', 'Tip proprietate': 'locuință nouă', 'Forma de proprietate': 'drept de proprietate', 'Liber de la': '2025-11-27', 'Tip vânzător': 'agenție', 'Informații suplimentare': 'terasă', 'Anul construcției': '2025', 'Lift': 'da', 'Tip clădire': 'ansamblu de apartamente', 'Material de construcție': 'beton', 'Tip geamuri': 'plastic', 'Facilități': 'aer condiționat', 'Siguranță': 'interfon uși / ferestre blindate supraveghere video', 'Media': 'telefon internet cablu tv', 'url': 'https://www.storia.ro/ro/oferta/apartament-cu-2-camere-n-zona-confecii-IDDTla.html'}
# [28/1135] Procesez: https://www.storia.ro/ro/oferta/apartament-2-camere-decomandat-militari-residence-IDFIJa.html
# anunt 28: {'Suprafață utilă': '50 m²', 'Numărul de camere': '2', 'Încălzire': 'centrală pe gaz', 'Etaj': '1/3', 'Chirie': 'fără informații', 'Stare': 'gata de utilizare', 'Tip proprietate': 'locuință nouă', 'Forma de proprietate': 'drept de proprietate', 'Liber de la': '2025-11-27', 'Tip vânzător': 'agenție', 'Informații suplimentare': 'balcon', 'Anul construcției': '2025', 'Lift': 'da', 'Tip clădire': 'ansamblu de apartamente', 'Material de construcție': 'beton', 'Siguranță': 'interfon supraveghere video uși / ferestre blindate', 'Media': 'internet', 'url': 'https://www.storia.ro/ro/oferta/apartament-2-camere-decomandat-militari-residence-IDFIJa.html'}
# [29/1135] Procesez: https://www.storia.ro/ro/oferta/apartamente-exclusiviste-bragadiru-IDAn03.html
# anunt 29: {'Suprafață utilă': '53 m²', 'Numărul de camere': '2', 'Încălzire': 'fără informații', 'Etaj': '1/6', 'Chirie': 'fără informații', 'Stare': 'în construcție', 'Tip proprietate': 'locuință nouă', 'Forma de proprietate': 'drept de proprietate', 'Liber de la': 'fără informații', 'Tip vânzător': 'agenție', 'Informații suplimentare': 'balcon', 'Anul construcției': '2025', 'Lift': 'da', 'Tip clădire': 'bloc', 'Material de construcție': 'cărămidă', 'Siguranță': 'uși / ferestre blindate interfon', 'url': 'https://www.storia.ro/ro/oferta/apartamente-exclusiviste-bragadiru-IDAn03.html'}
# [30/1135] Procesez: https://www.storia.ro/ro/oferta/apartament-2-camere-decomandat-militari-residence-IDFBgv.html
# anunt 30: {'Suprafață utilă': '50 m²', 'Numărul de camere': '2', 'Încălzire': 'centrală pe gaz', 'Etaj': '1/3', 'Chirie': 'fără informații', 'Stare': 'gata de utilizare', 'Tip proprietate': 'locuință nouă', 'Forma de proprietate': 'drept de proprietate', 'Liber de la': '2025-11-27', 'Tip vânzător': 'agenție', 'Informații suplimentare': 'balcon', 'Anul construcției': '2025', 'Lift': 'da', 'Tip clădire': 'ansamblu de apartamente', 'Material de construcție': 'beton', 'Siguranță': 'interfon supraveghere video uși / ferestre blindate', 'Media': 'internet', 'url': 'https://www.storia.ro/ro/oferta/apartament-2-camere-decomandat-militari-residence-IDFBgv.html'}
# [31/1135] Procesez: https://www.storia.ro/ro/oferta/2-camere-doamna-ghica-electronicii-sect-2-IDCRaZ.html
# anunt 31: {'Suprafață utilă': '30 m²', 'Numărul de camere': '2', 'Încălzire': 'fără informații', 'Etaj': '1/4', 'Chirie': 'fără informații', 'Stare': 'fără informații', 'Tip proprietate': 'locuință nouă', 'Forma de proprietate': 'fără informații', 'Liber de la': 'fără informații', 'Tip vânzător': 'agenție', 'Informații suplimentare': 'fără informații', 'Anul construcției': '1977', 'Lift': 'nu', 'url': 'https://www.storia.ro/ro/oferta/2-camere-doamna-ghica-electronicii-sect-2-IDCRaZ.html'}
# [32/1135] Procesez: https://www.storia.ro/ro/oferta/apartament-nou-cu-2-camere-IDDTVB.html
# anunt 32: {'Suprafață utilă': '53.45 m²', 'Numărul de camere': '2', 'Încălzire': 'centrală pe gaz', 'Etaj': '1/4', 'Chirie': 'fără informații', 'Stare': 'în construcție', 'Tip proprietate': 'locuință nouă', 'Forma de proprietate': 'drept de proprietate', 'Liber de la': '2025-11-27', 'Tip vânzător': 'agenție', 'Informații suplimentare': 'fără informații', 'Anul construcției': '2025', 'Lift': 'da', 'Tip clădire': 'ansamblu de apartamente', 'Material de construcție': 'beton', 'Tip geamuri': 'plastic', 'Facilități': 'aer condiționat', 'Siguranță': 'alarmă uși / ferestre blindate supraveghere video', 'Media': 'telefon internet cablu tv', 'url': 'https://www.storia.ro/ro/oferta/apartament-nou-cu-2-camere-IDDTVB.html'}
# [33/1135] Procesez: https://www.storia.ro/ro/oferta/apartament-luminos-2-camere-renovat-parter-breaza-IDEJj5.html
# anunt 33: {'Suprafață utilă': '40.3 m²', 'Numărul de camere': '2', 'Încălzire': 'centralizată', 'Etaj': 'parter', 'Chirie': 'fără informații', 'Stare': 'fără informații', 'Tip proprietate': 'locuință utilizată', 'Forma de proprietate': 'fără informații', 'Liber de la': 'fără informații', 'Tip vânzător': 'agenție', 'Informații suplimentare': 'balcon', 'Anul construcției': '1980', 'Lift': 'nu', 'Facilități': 'mobilier', 'Siguranță': 'uși / ferestre blindate', 'url': 'https://www.storia.ro/ro/oferta/apartament-luminos-2-camere-renovat-parter-breaza-IDEJj5.html'}
# [34/1135] Procesez: https://www.storia.ro/ro/oferta/rezervat-apartament-2-camere-zona-grivitei-IDFAEl.html
# anunt 34: {'Suprafață utilă': '48 m²', 'Numărul de camere': '2', 'Încălzire': 'fără informații', 'Etaj': '5', 'Chirie': 'fără informații', 'Stare': 'fără informații', 'Tip proprietate': 'locuință utilizată', 'Forma de proprietate': 'fără informații', 'Liber de la': 'fără informații', 'Tip vânzător': 'agenție', 'Informații suplimentare': 'balcon', 'Anul construcției': '1973', 'Lift': 'nu', 'url': 'https://www.storia.ro/ro/oferta/rezervat-apartament-2-camere-zona-grivitei-IDFAEl.html'}
# [35/1135] Procesez: https://www.storia.ro/ro/oferta/apartament-2-camere-decomandat-aleea-huedin-brancoveanu-comision-0-IDEM6X.html
# anunt 35: {'Suprafață utilă': '40 m²', 'Numărul de camere': '2', 'Încălzire': 'fără informații', 'Etaj': '7/10', 'Chirie': 'fără informații', 'Stare': 'gata de utilizare', 'Tip proprietate': 'locuință utilizată', 'Forma de proprietate': 'drept de proprietate', 'Liber de la': '2025-11-27', 'Tip vânzător': 'agenție', 'Informații suplimentare': 'balcon debara bucătărie separată', 'Anul construcției': '1975', 'Lift': 'da', 'Tip clădire': 'ansamblu de apartamente', 'Material de construcție': 'beton', 'Tip geamuri': 'plastic', 'Facilități': 'cuptor plită frigider', 'Siguranță': 'interfon uși / ferestre blindate', 'Media': 'telefon internet cablu tv', 'url': 'https://www.storia.ro/ro/oferta/apartament-2-camere-decomandat-aleea-huedin-brancoveanu-comision-0-IDEM6X.html'}
# [36/1135] Procesez: https://www.storia.ro/ro/oferta/comision-0-apartament-1-cam-37-mp-finisat-teras-11-mp-apahida-IDF6Qv.html
# anunt 36: {'Suprafață utilă': '37 m²', 'Numărul de camere': '2', 'Încălzire': 'centrală pe gaz', 'Etaj': 'parter/2', 'Chirie': 'fără informații', 'Stare': 'gata de utilizare', 'Tip proprietate': 'locuință nouă', 'Forma de proprietate': 'drept de proprietate', 'Liber de la': '2025-09-30', 'Tip vânzător': 'agenție', 'Informații suplimentare': 'balcon terasă garaj bucătărie separată', 'Anul construcției': '2025', 'Lift': 'nu', 'Tip clădire': 'bloc', 'Material de construcție': 'cărămidă', 'Tip geamuri': 'aluminiu', 'Siguranță': 'uși / ferestre blindate interfon zona imprejmuita', 'Media': 'internet cablu tv', 'url': 'https://www.storia.ro/ro/oferta/comision-0-apartament-1-cam-37-mp-finisat-teras-11-mp-apahida-IDF6Qv.html'}
# [37/1135] Procesez: https://www.storia.ro/ro/oferta/apartament-2-camere-obcini-etaj-1-2c-7609-IDFpMk.html
# anunt 37: {'Suprafață utilă': '42 m²', 'Numărul de camere': '2', 'Încălzire': 'centralizată', 'Etaj': '1/4', 'Chirie': 'fără informații', 'Stare': 'fără informații', 'Tip proprietate': 'locuință utilizată', 'Forma de proprietate': 'fără informații', 'Liber de la': 'fără informații', 'Tip vânzător': 'agenție', 'Informații suplimentare': 'balcon bucătărie separată', 'Anul construcției': '1990', 'Lift': 'nu', 'Tip geamuri': 'plastic', 'url': 'https://www.storia.ro/ro/oferta/apartament-2-camere-obcini-etaj-1-2c-7609-IDFpMk.html'}
# [38/1135] Procesez: https://www.storia.ro/ro/oferta/apartamente-2-camere-cu-cf-floresti-IDBvDs.html
# anunt 38: {'Suprafață utilă': '55 m²', 'Numărul de camere': '2', 'Încălzire': 'centrală pe gaz', 'Etaj': '2', 'Chirie': 'fără informații', 'Stare': 'fără informații', 'Tip proprietate': 'locuință nouă', 'Forma de proprietate': 'drept de proprietate', 'Liber de la': 'fără informații', 'Tip vânzător': 'agenție', 'Informații suplimentare': 'fără informații', 'Anul construcției': '2024', 'Lift': 'nu', 'Tip clădire': 'bloc', 'Material de construcție': 'cărămidă', 'Siguranță': 'uși / ferestre blindate interfon', 'Media': 'internet', 'url': 'https://www.storia.ro/ro/oferta/apartamente-2-camere-cu-cf-floresti-IDBvDs.html'}
# [39/1135] Procesez: https://www.storia.ro/ro/oferta/apartament-2-camere-54mp-etaj-1-zona-radu-negru-IDEFbZ.html
# anunt 39: {'Suprafață utilă': '48 m²', 'Numărul de camere': '2', 'Încălzire': 'centralizată', 'Etaj': '1/4', 'Chirie': 'fără informații', 'Stare': 'gata de utilizare', 'Tip proprietate': 'locuință nouă', 'Forma de proprietate': 'fără informații', 'Liber de la': 'fără informații', 'Tip vânzător': 'agenție', 'Informații suplimentare': 'balcon', 'Anul construcției': '1980', 'Lift': 'nu', 'Facilități': 'aer condiționat', 'url': 'https://www.storia.ro/ro/oferta/apartament-2-camere-54mp-etaj-1-zona-radu-negru-IDEFbZ.html'}
# [40/1135] Procesez: https://www.storia.ro/ro/oferta/complex-used-mixt-de-locuinte-ultra-premium-iasi-galata-IDuM7N.html
# anunt 40: {'Suprafață utilă': '55 m²', 'Numărul de camere': '2', 'Încălzire': 'centralizată', 'Etaj': '1/2', 'Chirie': 'fără informații', 'Stare': 'gata de utilizare', 'Tip proprietate': 'locuință nouă', 'Forma de proprietate': 'drept de proprietate', 'Liber de la': 'fără informații', 'Tip vânzător': 'agenție', 'Informații suplimentare': 'balcon', 'Anul construcției': '2024', 'Lift': 'nu', 'Tip clădire': 'bloc', 'Material de construcție': 'cărămidă', 'Tip geamuri': 'aluminiu', 'Siguranță': 'alarmă uși / ferestre blindate supraveghere video', 'Media': 'cablu tv internet', 'url': 'https://www.storia.ro/ro/oferta/complex-used-mixt-de-locuinte-ultra-premium-iasi-galata-IDuM7N.html'}
# [41/1135] Procesez: https://www.storia.ro/ro/oferta/apartament-cu-2-camere-90-mp-construiti-zona-centrala-IDFpXb.html
# anunt 41: {'Suprafață utilă': '45 m²', 'Numărul de camere': '2', 'Încălzire': 'centrală pe gaz', 'Etaj': '2/2', 'Chirie': 'fără informații', 'Stare': 'gata de utilizare', 'Tip proprietate': 'locuință utilizată', 'Forma de proprietate': 'drept de proprietate', 'Liber de la': '2025-10-28', 'Tip vânzător': 'agenție', 'Informații suplimentare': 'fără informații', 'Anul construcției': '1940', 'Lift': 'nu', 'Tip clădire': 'ansamblu de apartamente', 'Material de construcție': 'cărămidă', 'Media': 'telefon internet cablu tv', 'url': 'https://www.storia.ro/ro/oferta/apartament-cu-2-camere-90-mp-construiti-zona-centrala-IDFpXb.html'}
# [42/1135] Procesez: https://www.storia.ro/ro/oferta/comision-0-apartament-cu-3-camere-terasa-si-gradina-zona-rahova-IDELF8.html
# anunt 42: {'Suprafață utilă': '84.75 m²', 'Numărul de camere': '3', 'Încălzire': 'centrală pe gaz', 'Etaj': 'parter/9', 'Chirie': 'fără informații', 'Stare': 'în construcție', 'Tip proprietate': 'locuință nouă', 'Forma de proprietate': 'drept de proprietate', 'Liber de la': 'fără informații', 'Tip vânzător': 'agenție', 'Informații suplimentare': 'terasă grădină bucătărie separată', 'Anul construcției': '2025', 'Lift': 'da', 'Tip clădire': 'ansamblu de apartamente', 'Material de construcție': 'beton', 'Tip geamuri': 'plastic', 'Siguranță': 'interfon supraveghere video uși / ferestre blindate', 'Media': 'telefon internet cablu tv', 'url': 'https://www.storia.ro/ro/oferta/comision-0-apartament-cu-3-camere-terasa-si-gradina-zona-rahova-IDELF8.html'}
# [43/1135] Procesez: https://www.storia.ro/ro/oferta/apartament-3-camere-zona-spitalului-de-copii-IDFILb.html
# anunt 43: {'Suprafață utilă': '50 m²', 'Numărul de camere': '3', 'Încălzire': 'fără informații', 'Etaj': 'fără informații', 'Chirie': 'fără informații', 'Stare': 'fără informații', 'Tip proprietate': 'locuință utilizată', 'Forma de proprietate': 'fără informații', 'Liber de la': 'fără informații', 'Tip vânzător': 'agenție', 'Informații suplimentare': 'fără informații', 'Lift': 'nu', 'url': 'https://www.storia.ro/ro/oferta/apartament-3-camere-zona-spitalului-de-copii-IDFILb.html'}
# [44/1135] Procesez: https://www.storia.ro/ro/oferta/garsonier-tip-studio-33-20-mp-utili-si-balcon-5-80-mp-magnolia-IDEoN0.html
# anunt 44: {'Suprafață utilă': '33 m²', 'Numărul de camere': '1', 'Încălzire': 'centralizată', 'Etaj': '1', 'Chirie': 'fără informații', 'Stare': 'fără informații', 'Tip proprietate': 'locuință utilizată', 'Forma de proprietate': 'fără informații', 'Liber de la': 'fără informații', 'Tip vânzător': 'agenție', 'Informații suplimentare': 'balcon', 'Anul construcției': '2025', 'Lift': 'da', 'url': 'https://www.storia.ro/ro/oferta/garsonier-tip-studio-33-20-mp-utili-si-balcon-5-80-mp-magnolia-IDEoN0.html'}
# [45/1135] Procesez: https://www.storia.ro/ro/oferta/apartament-decomandat-cu-2-camere-zona-grand-arena-mall-sector-4-IDENse.html
# anunt 45: {'Suprafață utilă': '45.9 m²', 'Numărul de camere': '2', 'Încălzire': 'centrală pe gaz', 'Etaj': '3/6', 'Chirie': 'fără informații', 'Stare': 'în construcție', 'Tip proprietate': 'locuință nouă', 'Forma de proprietate': 'drept de proprietate', 'Liber de la': '2025-11-20', 'Tip vânzător': 'agenție', 'Informații suplimentare': 'balcon bucătărie separată', 'Anul construcției': '2025', 'Lift': 'da', 'Tip clădire': 'ansamblu de apartamente', 'Material de construcție': 'beton', 'Tip geamuri': 'plastic', 'Siguranță': 'interfon uși / ferestre blindate', 'Media': 'internet cablu tv', 'url': 'https://www.storia.ro/ro/oferta/apartament-decomandat-cu-2-camere-zona-grand-arena-mall-sector-4-IDENse.html'}
# [46/1135] Procesez: https://www.storia.ro/ro/oferta/apartament-decomandat-cu-2-camere-n-aradul-nou-IDxxie.html
# anunt 46: {'Suprafață utilă': '53.92 m²', 'Numărul de camere': '2', 'Încălzire': 'centrală pe gaz', 'Etaj': '4/4', 'Chirie': 'fără informații', 'Stare': 'gata de utilizare', 'Tip proprietate': 'locuință utilizată', 'Forma de proprietate': 'drept de proprietate', 'Liber de la': '2025-11-27', 'Tip vânzător': 'agenție', 'Informații suplimentare': 'balcon', 'Anul construcției': '1980', 'Lift': 'nu', 'Tip clădire': 'ansamblu de apartamente', 'Material de construcție': 'beton', 'Tip geamuri': 'plastic', 'Facilități': 'mobilier cuptor plită mașină de spălat', 'Siguranță': 'interfon uși / ferestre blindate', 'url': 'https://www.storia.ro/ro/oferta/apartament-decomandat-cu-2-camere-n-aradul-nou-IDxxie.html'}
# [47/1135] Procesez: https://www.storia.ro/ro/oferta/apartament-cu-2-camere-teras-generoas-monia-IDFb6l.html
# anunt 47: {'Suprafață utilă': '65.7 m²', 'Numărul de camere': '2', 'Încălzire': 'fără informații', 'Etaj': '2/3', 'Chirie': 'fără informații', 'Stare': 'fără informații', 'Tip proprietate': 'locuință nouă', 'Forma de proprietate': 'drept de proprietate', 'Liber de la': '2025-11-27', 'Tip vânzător': 'agenție', 'Informații suplimentare': 'balcon terasă debara', 'Anul construcției': '2024', 'Lift': 'nu', 'Tip clădire': 'ansamblu de apartamente', 'Material de construcție': 'cărămidă', 'Tip geamuri': 'plastic', 'Facilități': 'aer condiționat', 'Siguranță': 'supraveghere video uși / ferestre blindate interfon', 'Media': 'telefon internet cablu tv', 'url': 'https://www.storia.ro/ro/oferta/apartament-cu-2-camere-teras-generoas-monia-IDFb6l.html'}
# [48/1135] Procesez: https://www.storia.ro/ro/oferta/vnd-apartament-3-camere-n-hunedoara-zona-om-pa-eliberrii-64-mp-IDEJqQ.html
# anunt 48: {'Suprafață utilă': '64 m²', 'Numărul de camere': '3', 'Încălzire': 'centrală pe gaz', 'Etaj': 'parter/2', 'Chirie': 'fără informații', 'Stare': 'gata de utilizare', 'Tip proprietate': 'locuință utilizată', 'Forma de proprietate': 'drept de proprietate', 'Liber de la': 'fără informații', 'Tip vânzător': 'agenție', 'Informații suplimentare': 'beci', 'Lift': 'nu', 'Tip clădire': 'bloc', 'Material de construcție': 'cărămidă', 'Tip geamuri': 'plastic', 'Facilități': 'mobilier frigider cuptor', 'Siguranță': 'interfon', 'Media': 'internet cablu tv', 'url': 'https://www.storia.ro/ro/oferta/vnd-apartament-3-camere-n-hunedoara-zona-om-pa-eliberrii-64-mp-IDEJqQ.html'}
# [49/1135] Procesez: https://www.storia.ro/ro/oferta/apartament-panoramic-cu-2-camere-zona-confecii-IDEr67.html
# anunt 49: {'Suprafață utilă': '55 m²', 'Numărul de camere': '2', 'Încălzire': 'centrală pe gaz', 'Etaj': '5/5', 'Chirie': 'fără informații', 'Stare': 'gata de utilizare', 'Tip proprietate': 'locuință utilizată', 'Forma de proprietate': 'drept de proprietate', 'Liber de la': '2025-11-27', 'Tip vânzător': 'agenție', 'Informații suplimentare': 'balcon bucătărie separată', 'Anul construcției': '2007', 'Lift': 'nu', 'Tip clădire': 'ansamblu de apartamente', 'Material de construcție': 'beton celular', 'Facilități': 'cuptor plită frigider mașină de spălat aer condiționat', 'Siguranță': 'interfon', 'Media': 'telefon internet cablu tv', 'url': 'https://www.storia.ro/ro/oferta/apartament-panoramic-cu-2-camere-zona-confecii-IDEr67.html'}
# [50/1135] Procesez: https://www.storia.ro/ro/oferta/vanzare-garsoniera-spatioasa-direct-dezvoltator-IDFINt.html
# anunt 50: {'Suprafață utilă': '41 m²', 'Numărul de camere': '1', 'Încălzire': 'altul', 'Etaj': '1/6', 'Chirie': 'fără informații', 'Stare': 'în construcție', 'Tip proprietate': 'locuință nouă', 'Forma de proprietate': 'drept de proprietate', 'Liber de la': 'fără informații', 'Tip vânzător': 'agenție', 'Informații suplimentare': 'balcon', 'Anul construcției': '2025', 'Lift': 'da', 'Material de construcție': 'beton', 'Tip geamuri': 'plastic', 'Siguranță': 'interfon uși / ferestre blindate', 'Media': 'telefon internet cablu tv', 'url': 'https://www.storia.ro/ro/oferta/vanzare-garsoniera-spatioasa-direct-dezvoltator-IDFINt.html'}
# [51/1135] Procesez: https://www.storia.ro/ro/oferta/apartament-premium-tip-duplex-190-mp-mobilat-utilat-IDE8nb.html
# anunt 51: {'Suprafață utilă': '190 m²', 'Numărul de camere': '5', 'Încălzire': 'centrală pe gaz', 'Etaj': '3/4', 'Chirie': 'fără informații', 'Stare': 'gata de utilizare', 'Tip proprietate': 'locuință utilizată', 'Forma de proprietate': 'drept de proprietate', 'Liber de la': 'fără informații', 'Tip vânzător': 'agenție', 'Informații suplimentare': 'balcon terasă scară interioară bucătărie separată', 'Anul construcției': '2013', 'Lift': 'nu', 'Tip clădire': 'bloc', 'Material de construcție': 'beton armat', 'Tip geamuri': 'plastic', 'Facilități': 'mobilier mașină de spălat mașină de spălat vasele frigider plită cuptor aer condiționat', 'Siguranță': 'uși / ferestre blindate', 'url': 'https://www.storia.ro/ro/oferta/apartament-premium-tip-duplex-190-mp-mobilat-utilat-IDE8nb.html'}
# [52/1135] Procesez: https://www.storia.ro/ro/oferta/apartament-2-camere-militari-residence-mobilat-parcare-inclusa-chiri-IDxpQy.html
# anunt 52: {'Suprafață utilă': '50 m²', 'Numărul de camere': '2', 'Încălzire': 'centralizată', 'Etaj': '1/8', 'Chirie': 'fără informații', 'Stare': 'gata de utilizare', 'Tip proprietate': 'locuință nouă', 'Forma de proprietate': 'fără informații', 'Liber de la': 'fără informații', 'Tip vânzător': 'agenție', 'Informații suplimentare': 'balcon', 'Anul construcției': '2009', 'Lift': 'da', 'Facilități': 'aer condiționat', 'url': 'https://www.storia.ro/ro/oferta/apartament-2-camere-militari-residence-mobilat-parcare-inclusa-chiri-IDxpQy.html'}
# [53/1135] Procesez: https://www.storia.ro/ro/oferta/etaj-1-apartament-2-camere-calarasilor-IDFlFJ.html
# anunt 53: {'Suprafață utilă': '49 m²', 'Numărul de camere': '2', 'Încălzire': 'centralizată', 'Etaj': '1/8', 'Chirie': 'fără informații', 'Stare': 'gata de utilizare', 'Tip proprietate': 'locuință nouă', 'Forma de proprietate': 'fără informații', 'Liber de la': 'fără informații', 'Tip vânzător': 'agenție', 'Informații suplimentare': 'balcon', 'Anul construcției': '1983', 'Lift': 'nu', 'url': 'https://www.storia.ro/ro/oferta/etaj-1-apartament-2-camere-calarasilor-IDFlFJ.html'}
# [54/1135] Procesez: https://www.storia.ro/ro/oferta/apartament-3-camere-66-mp-utili-etaj-2-10-lift-central-IDES1Y.html
# anunt 54: {'Suprafață utilă': '66 m²', 'Numărul de camere': '3', 'Încălzire': 'centrală pe gaz', 'Etaj': '2/10', 'Chirie': 'fără informații', 'Stare': 'gata de utilizare', 'Tip proprietate': 'locuință utilizată', 'Forma de proprietate': 'drept de proprietate', 'Liber de la': '2025-11-17', 'Tip vânzător': 'agenție', 'Informații suplimentare': 'balcon', 'Lift': 'da', 'Tip clădire': 'ansamblu de apartamente', 'Material de construcție': 'cărămidă', 'Tip geamuri': 'plastic', 'Siguranță': 'uși / ferestre blindate interfon', 'Media': 'internet', 'url': 'https://www.storia.ro/ro/oferta/apartament-3-camere-66-mp-utili-etaj-2-10-lift-central-IDES1Y.html'}
# [55/1135] Procesez: https://www.storia.ro/ro/oferta/apartament-3-camere-50mp-etaj-intermediar-zona-porii-IDF1Y5.html
# anunt 55: {'Suprafață utilă': '50 m²', 'Numărul de camere': '3', 'Încălzire': 'centrală pe gaz', 'Etaj': '1/4', 'Chirie': 'fără informații', 'Stare': 'gata de utilizare', 'Tip proprietate': 'locuință utilizată', 'Forma de proprietate': 'drept de proprietate', 'Liber de la': '2025-11-27', 'Tip vânzător': 'agenție', 'Informații suplimentare': 'terasă', 'Lift': 'nu', 'Tip clădire': 'ansamblu de apartamente', 'Material de construcție': 'cărămidă', 'Tip geamuri': 'plastic', 'Facilități': 'cuptor frigider mașină de spălat TV aer condiționat', 'Siguranță': 'uși / ferestre blindate interfon', 'Media': 'internet telefon', 'url': 'https://www.storia.ro/ro/oferta/apartament-3-camere-50mp-etaj-intermediar-zona-porii-IDF1Y5.html'}
# [56/1135] Procesez: https://www.storia.ro/ro/oferta/apartament-cu-3-camere-la-mare-micos-estate-mamaia-nord-IDF6Wy.html
# anunt 56: {'Suprafață utilă': '85 m²', 'Numărul de camere': '3', 'Încălzire': 'centrală pe gaz', 'Etaj': '1/4', 'Chirie': 'fără informații', 'Stare': 'în construcție', 'Tip proprietate': 'locuință nouă', 'Forma de proprietate': 'drept de proprietate', 'Liber de la': '2025-09-30', 'Tip vânzător': 'agenție', 'Informații suplimentare': 'balcon', 'Anul construcției': '2026', 'Lift': 'da', 'Tip clădire': 'bloc', 'Material de construcție': 'beton', 'Tip geamuri': 'plastic', 'Siguranță': 'uși / ferestre blindate interfon', 'Media': 'internet cablu tv telefon', 'url': 'https://www.storia.ro/ro/oferta/apartament-cu-3-camere-la-mare-micos-estate-mamaia-nord-IDF6Wy.html'}
# [57/1135] Procesez: https://www.storia.ro/ro/oferta/apartament-3-camere-72-mp-zona-frumoasa-IDFBNr.html
# anunt 57: {'Suprafață utilă': '72 m²', 'Numărul de camere': '3', 'Încălzire': 'centrală pe gaz', 'Etaj': '7/8', 'Chirie': 'fără informații', 'Stare': 'gata de utilizare', 'Tip proprietate': 'locuință utilizată', 'Forma de proprietate': 'drept de proprietate', 'Liber de la': '2025-11-17', 'Tip vânzător': 'agenție', 'Informații suplimentare': 'balcon', 'Anul construcției': '1985', 'Lift': 'da', 'Tip clădire': 'ansamblu de apartamente', 'Material de construcție': 'beton', 'Tip geamuri': 'plastic', 'Facilități': 'frigider mașină de spălat TV plită mașină de spălat vasele aer condiționat', 'Siguranță': 'uși / ferestre blindate interfon', 'Media': 'internet', 'url': 'https://www.storia.ro/ro/oferta/apartament-3-camere-72-mp-zona-frumoasa-IDFBNr.html'}
# [58/1135] Procesez: https://www.storia.ro/ro/oferta/apartament-3-camere-mobilat-scoala-americana-IDFHNk.html
# anunt 58: {'Suprafață utilă': '85 m²', 'Numărul de camere': '3', 'Încălzire': 'altul', 'Etaj': '1/5', 'Chirie': 'fără informații', 'Stare': 'gata de utilizare', 'Tip proprietate': 'locuință utilizată', 'Forma de proprietate': 'drept de proprietate', 'Liber de la': '2025-11-27', 'Tip vânzător': 'agenție', 'Informații suplimentare': 'terasă garaj', 'Anul construcției': '2021', 'Lift': 'da', 'Tip clădire': 'ansamblu de apartamente', 'Material de construcție': 'cărămidă', 'Tip geamuri': 'plastic', 'Facilități': 'mobilier cuptor plită frigider mașină de spălat mașină de spălat vasele aer condiționat', 'Siguranță': 'interfon supraveghere video uși / ferestre blindate', 'Media': 'telefon internet cablu tv', 'url': 'https://www.storia.ro/ro/oferta/apartament-3-camere-mobilat-scoala-americana-IDFHNk.html'}
# [59/1135] Procesez: https://www.storia.ro/ro/oferta/apartament-cu-3-camere-62-mp-zona-pajura-IDDFIN.html
# anunt 59: {'Suprafață utilă': '62 m²', 'Numărul de camere': '3', 'Încălzire': 'centrală pe gaz', 'Etaj': '1/3', 'Chirie': 'fără informații', 'Stare': 'gata de utilizare', 'Tip proprietate': 'locuință utilizată', 'Forma de proprietate': 'drept de proprietate', 'Liber de la': '2025-11-27', 'Tip vânzător': 'agenție', 'Informații suplimentare': 'balcon', 'Anul construcției': '1965', 'Lift': 'nu', 'Tip clădire': 'ansamblu de apartamente', 'Material de construcție': 'beton', 'Tip geamuri': 'plastic', 'Facilități': 'cuptor frigider mașină de spălat TV aer condiționat', 'Siguranță': 'uși / ferestre blindate interfon', 'Media': 'cablu tv internet telefon', 'url': 'https://www.storia.ro/ro/oferta/apartament-cu-3-camere-62-mp-zona-pajura-IDDFIN.html'}
# [60/1135] Procesez: https://www.storia.ro/ro/oferta/apartament-cu-3-camere-de-vanzare-buhusi-IDDKIR.html
# anunt 60: {'Suprafață utilă': '58.61 m²', 'Numărul de camere': '3', 'Încălzire': 'centralizată', 'Etaj': '4', 'Chirie': 'fără informații', 'Stare': 'fără informații', 'Tip proprietate': 'locuință utilizată', 'Forma de proprietate': 'fără informații', 'Liber de la': 'fără informații', 'Tip vânzător': 'agenție', 'Informații suplimentare': 'balcon', 'Anul construcției': '1985', 'Lift': 'nu', 'Facilități': 'mobilier', 'Siguranță': 'uși / ferestre blindate', 'url': 'https://www.storia.ro/ro/oferta/apartament-cu-3-camere-de-vanzare-buhusi-IDDKIR.html'}
# [61/1135] Procesez: https://www.storia.ro/ro/oferta/ap-2-cam-martie-2026-zona-militari-residence-IDFIJw.html
# anunt 61: {'Suprafață utilă': '45 m²', 'Numărul de camere': '2', 'Încălzire': 'centrală pe gaz', 'Etaj': '2/6', 'Chirie': 'fără informații', 'Stare': 'în construcție', 'Tip proprietate': 'locuință nouă', 'Forma de proprietate': 
1135] Procesez: https://www.storia.ro/ro/oferta/apartament-cu-2-camere-decomandate-lupeni-strada-parngului-IDE8mu.html
#     ⚠ fetch_html a eșuat, retry 1x...
#   -> ❌ Ignor eroarea și continui: 403 Client Error: Forbidden for url: https://www.storia.ro/ro/oferta/apartament-cu-2-camere-decomandate-lupeni-strada-parngului-IDE8mu.html
# [283/1135] Procesez: https://www.storia.ro/ro/oferta/apartament-3-camere-spatios-locuinta-ideala-pentru-confortul-familiei-IDDZZy.html
#     ⚠ fetch_html a eșuat, retry 1x...
#   -> ❌ Ignor eroarea și continui: 403 Client Error: Forbidden for url: https://www.storia.ro/ro/oferta/apartament-3-camere-spatios-locuinta-ideala-pentru-confortul-familiei-IDDZZy.html
# [284/1135] Procesez: https://www.storia.ro/ro/oferta/apartament-3-camere-decomandat-centrala-toporasi-prelungirea-ferentari-IDFIOS.html
#     ⚠ fetch_html a eșuat, retry 1x...
#   -> ❌ Ignor eroarea și continui: 403 Client Error: Forbidden for url: https://www.storia.ro/ro/oferta/apartament-3-camere-decomandat-centrala-toporasi-prelungirea-ferentari-IDFIOS.html
# [285/1135] Procesez: https://www.storia.ro/ro/oferta/2-camere-bucatarie-inchisa-finisaje-premium-IDEBlv.html
#     ⚠ fetch_html a eșuat, retry 1x...
#   -> ❌ Ignor eroarea și continui: 403 Client Error: Forbidden for url: https://www.storia.ro/ro/oferta/2-camere-bucatarie-inchisa-finisaje-premium-IDEBlv.html
# [286/1135] Procesez: https://www.storia.ro/ro/oferta/zona-shopping-mall-rate-fixe-pe-30-de-ani-doar-cu-buletinul-IDCEm6.html
#     ⚠ fetch_html a eșuat, retry 1x...
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /tmp/ipython-input-2941792886.py in <cell line: 0>()
#       4         try:
# ----> 5             html = fetch_html(ad_url)
#       6         except Exception as e:
#
# /tmp/ipython-input-588554049.py in fetch_html(url)
#      13     resp = requests.get(url, headers=headers, timeout=10)
# ---> 14     resp.raise_for_status()
#      15     return resp.text
#
# /usr/local/lib/python3.12/dist-packages/requests/models.py in raise_for_status(self)
#    1025         if http_error_msg:
# -> 1026             raise HTTPError(http_error_msg, response=self)
#    1027
#
# HTTPError: 403 Client Error: Forbidden for url: https://www.storia.ro/ro/oferta/zona-shopping-mall-rate-fixe-pe-30-de-ani-doar-cu-buletinul-IDCEm6.html
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-2941792886.py in <cell line: 0>()
#       6         except Exception as e:
#       7             print(f"    ⚠ fetch_html a eșuat, retry 1x...")
# ----> 8             html = fetch_html(ad_url)  # retry once
#       9
#      10         details = parse_storia_details(html)
#
# /tmp/ipython-input-588554049.py in fetch_html(url)
#      11
#      12 def fetch_html(url: str) -> str:
# ---> 13     resp = requests.get(url, headers=headers, timeout=10)
#      14     resp.raise_for_status()
#      15     return resp.text
#
# /usr/local/lib/python3.12/dist-packages/requests/api.py in get(url, params, **kwargs)
#      71     """
#      72
# ---> 73     return request("get", url, params=params, **kwargs)
#      74
#      75
#
# /usr/local/lib/python3.12/dist-packages/requests/api.py in request(method, url, **kwargs)
#      57     # cases, and look like a memory leak in others.
#      58     with sessions.Session() as session:
# ---> 59         return session.request(method=method, url=url, **kwargs)
#      60
#      61
#
# /usr/local/lib/python3.12/dist-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     587         }
#     588         send_kwargs.update(settings)
# --> 589         resp = self.send(prep, **send_kwargs)
#     590
#     591         return resp
#
# /usr/local/lib/python3.12/dist-packages/requests/sessions.py in send(self, request, **kwargs)
#     701
#     702         # Send the request
# --> 703         r = adapter.send(request, **kwargs)
#     704
#     705         # Total elapsed time of the request (approximately)
#
# /usr/local/lib/python3.12/dist-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     665
#     666         try:
# --> 667             resp = conn.urlopen(
#     668                 method=request.method,
#     669                 url=url,
#
# /usr/local/lib/python3.12/dist-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     785
#     786             # Make the request on the HTTPConnection object
# --> 787             response = self._make_request(
#     788                 conn,
#     789                 method,
#
# /usr/local/lib/python3.12/dist-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     532         # Receive the response from the server
#     533         try:
# --> 534             response = conn.getresponse()
#     535         except (BaseSSLError, OSError) as e:
#     536             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# /usr/local/lib/python3.12/dist-packages/urllib3/connection.py in getresponse(self)
#     563
#     564         # Get the response from http.client.HTTPConnection
# --> 565         httplib_response = super().getresponse()
#     566
#     567         try:
#
# /usr/lib/python3.12/http/client.py in getresponse(self)
#    1428         try:
#    1429             try:
# -> 1430                 response.begin()
#    1431             except ConnectionError:
#    1432                 self.close()
#
# /usr/lib/python3.12/http/client.py in begin(self)
#     329         # read until we get a non-100 response
#     330         while True:
# --> 331             version, status, reason = self._read_status()
#     332             if status != CONTINUE:
#     333                 break
#
# /usr/lib/python3.12/http/client.py in _read_status(self)
#     290
#     291     def _read_status(self):
# --> 292         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     293         if len(line) > _MAXLINE:
#     294             raise LineTooLong("status line")
#
# /usr/lib/python3.12/socket.py in readinto(self, b)
#     718         while True:
#     719             try:
# --> 720                 return self._sock.recv_into(b)
#     721             except timeout:
#     722                 self._timeout_occurred = True
#
# /usr/lib/python3.12/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1249                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1250                   self.__class__)
# -> 1251             return self.read(nbytes, buffer)
#    1252         else:
#    1253             return super().recv_into(buffer, nbytes, flags)
#
# /usr/lib/python3.12/ssl.py in read(self, len, buffer)
#    1101         try:
#    1102             if buffer is not None:
# -> 1103                 return self._sslobj.read(len, buffer)
#    1104             else:
#    1105                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
# !pip install pandas openpyxl
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Requirement already satisfied: openpyxl in /usr/local/lib/python3.12/dist-packages (3.1.5)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.12/dist-packages (from openpyxl) (2.0.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
import re
import pandas as pd
df = pd.DataFrame(all_ads_data)
print(df.head())
# Out:
#   Suprafață utilă Numărul de camere        Încălzire      Etaj  \
# 0           31 m²                 1  fără informații         2
# 1           38 m²                 1  centrală pe gaz       5/6
# 2         68.5 m²                 3  centrală pe gaz       3/3
# 3           52 m²                 2  centrală pe gaz  parter/4
# 4          119 m²                 4  fără informații       3/3
#
#             Chirie              Stare     Tip proprietate  \
# 0  fără informații    fără informații  locuință utilizată
# 1  fără informații  gata de utilizare  locuință utilizată
# 2  fără informații  gata de utilizare  locuință utilizată
# 3  fără informații  gata de utilizare  locuință utilizată
# 4  fără informații    fără informații  locuință utilizată
#
#    Forma de proprietate      Liber de la Tip vânzător  \
# 0       fără informații  fără informații      agenție
# 1  drept de proprietate       2025-11-27      agenție
# 2  drept de proprietate  fără informații      agenție
# 3  drept de proprietate       2025-11-20      agenție
# 4       fără informații  fără informații      agenție
#
#         Informații suplimentare Anul construcției Lift  \
# 0               fără informații              2022   nu
# 1     balcon bucătărie separată              2014   da
# 2               fără informații              2025   nu
# 3               fără informații               NaN   nu
# 4  terasă beci scară interioară              2023   da
#
#                        Facilități  \
# 0                        mobilier
# 1  mobilier cuptor plită frigider
# 2                             NaN
# 3                             NaN
# 4                 aer condiționat
#
#                                            Siguranță  \
# 0                                 supraveghere video
# 1                   interfon uși / ferestre blindate
# 2                                                NaN
# 3                                                NaN
# 4  alarmă interfon supraveghere video uși / feres...
#
#                                                  url Material de construcție  \
# 0  https://www.storia.ro/ro/oferta/apartament-1-c...                     NaN
# 1  https://www.storia.ro/ro/oferta/locuinta-moder...                   beton
# 2  https://www.storia.ro/ro/oferta/3-camere-cu-te...                   beton
# 3  https://www.storia.ro/ro/oferta/apartament-2-c...                   beton
# 4  https://www.storia.ro/ro/oferta/apartament-4-c...                   beton
#
#   Tip geamuri             Media              Tip clădire
# 0         NaN               NaN                      NaN
# 1     plastic  telefon internet                      NaN
# 2     plastic           telefon  ansamblu de apartamente
# 3     plastic               NaN  ansamblu de apartamente
# 4         NaN               NaN  ansamblu de apartamente

# %%
def parse_surface_m2(value):
    """
    Primește un string gen '45 m²' sau '45,5 m²'
    și întoarce un număr (float sau int).
    """
    if not isinstance(value, str):
        return None

    # căutăm prima apariție de număr (ex: 45, 45.5, 45,5)
    m = re.search(r'(\d+[.,]?\d*)', value)
    if not m:
        return None

    num_str = m.group(1).replace(",", ".")
    try:
        val = float(num_str)
        # dacă vrei întreg, poți converti la int:
        return int(round(val))
    except ValueError:
        return None

df["Suprafata_utila_m2"] = df["Suprafață utilă"].apply(parse_surface_m2)

# %%
output_csv = "storia_apartamente_normalizat.csv"
output_xlsx = "storia_apartamente_normalizat.xlsx"

# CSV (cu BOM pentru diacritice ok în Excel pe Windows)
df.to_csv(output_csv, index=False, encoding="utf-8-sig")

# Excel
df.to_excel(output_xlsx, index=False)

print("Fișiere salvate:")
print(" -", output_csv)
print(" -", output_xlsx)
# Out:
# Fișiere salvate:
#  - storia_apartamente_normalizat.csv
#  - storia_apartamente_normalizat.xlsx
